# %%
import sys, os
sys.path.append(os.path.abspath("../"))

# %%
from nutrimap_app.KMeanModel import build_kmeans_model

model, df_clusters = build_kmeans_model()

# %%
from nutrimap_app.KMeanModel import CLUSTERED_DATA_PATH
import pandas as pd

df_clusters = pd.read_csv(CLUSTERED_DATA_PATH)
df_clusters.sample(30, random_state=64)
# Out:
#                                               food_item  fat_g  satfat_g  \
# 4898  Lamb, New Zealand, imported, loin saddle, sepa...   5.32     1.960
# 185                         Candies, NESTLE, CHUNKY Bar  27.50    12.500
# 1586  Pears, dried, sulfured, stewed, without added ...   0.31     0.017
# 7283  Beverages, fruit punch-flavor drink, powder, w...   0.01     0.006
# 3496                     SMART SOUP, Moroccan Chick Pea   1.06     0.180
# 3280     Babyfood, fruit, pears and pineapple, strained   0.10     0.007
# 3416              Turkey, whole, breast, meat only, raw   1.48     0.289
# 1088                                    Tomatillos, raw   1.02     0.139
# 3452  Turkey, retail parts, drumstick, meat and skin...   9.37     2.307
# 6476                                Soy flour, defatted   1.22     0.136
# 407   Pork, fresh, variety meats and by-products, st...  10.14     4.025
# 1623  Pork, cured, ham and water product, rump, bone...  12.13     3.984
# ...

# %%
import importlib
import nutrimap_app.KMeanModel as km

# reload in case you just edited KMeanModel.py
importlib.reload(km)

# 1) run main clustering
model, df_clusters = km.build_kmeans_model()

# 2) run subclustering on that result
df_final = km.subclustering(df_clusters)

# df_final.sample(30, random_state=42)
df_final[df_final["cluster"] == 3].sample(20, random_state=44)
# Out:
#                                               food_item   fat_g  satfat_g  \
# 4341  Beef, Australian, imported, Wagyu, external fa...   63.27    22.504
# 3643  Salad dressing, mayonnaise, soybean and safflo...   79.40     8.600
# 449                           Pork, fresh, backfat, raw   88.69    32.210
# 3665                                Oil, apricot kernel  100.00     6.300
# 6241  Oil, industrial, soy (partially hydrogenated )...  100.00    28.421
# 3649                      Oil, sesame, salad or cooking  100.00    14.200
# 858   Pork, fresh, variety meats and by-products, jo...   69.61    25.260
# 4032                Salad dressing, french, home recipe   70.20    12.600
# 5008  Oil, industrial, canola (partially hydrogenate...  100.00    10.117
# 5018                   Oil, vegetable, soybean, refined  100.00    15.251
# 5725  Beef, New Zealand, imported, intermuscular fat...   63.78    28.500
# 3650           Oil, sunflower, linoleic (less than 60%)  100.00    10.100
# ...

# %%
from nutrimap_app.KMeanModel import build_kmeans_model, subclustering, assign_plate_role

model, df_clusters = build_kmeans_model()

df_sub = subclustering(df_clusters)
df_final = assign_plate_role(df_sub)

df_final[["food_item", "cluster", "subcluster", "plate_role"]].sample(20)
# Out:
#                                               food_item  cluster  subcluster  \
# 2111  Beef, composite of trimmed retail cuts, separa...        4          -1
# 6896  Lima beans, thin seeded (baby), mature seeds, raw        1           0
# 6175  Infant formula, MEAD JOHNSON, ENFAMIL, LIPIL, ...        0           1
# 2451                     OLIVE GARDEN, lasagna classico        4          -1
# 4695  KFC, Fried Chicken, EXTRA CRISPY, Skin and Bre...        2          -1
# 2127  Beef, rib, whole (ribs 6-12), separable lean a...        2          -1
# 386   Mollusks, scallop, (bay and sea), cooked, steamed        4          -1
# 3984                      Babyfood, cookie, baby, fruit        1           1
# 1643  Infant formula, MEAD JOHNSON, ENFAMIL, NUTRAMI...        1           1
# 5501  Chicken, dark meat, drumstick, meat only, with...        4          -1
# 5489                            Ostrich, oyster, cooked        4          -1
# ...
